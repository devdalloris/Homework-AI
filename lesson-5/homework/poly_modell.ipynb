# %%
import pandas as pd
import numpy as np
import matplotlib as plt

from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('advertising.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
X=df.drop(columns=['Sales']).values
y=df['Sales'].values

# %%
stc_sc = StandardScaler()
make_poly = PolynomialFeatures(degree = 2, include_bias=False, interaction_only=True)
lin_reg = LinearRegression()

# %%
X = stc_sc.fit_transform(X)
X[:5]
# Out:
# array([[ 0.96985227,  0.98152247,  1.77894547],
#        [-1.19737623,  1.08280781,  0.66957876],
#        [-1.51615499,  1.52846331,  1.78354865],
#        [ 0.05204968,  1.21785493,  1.28640506],
#        [ 0.3941822 , -0.84161366,  1.28180188]])

# %%
X=make_poly.fit_transform(X)
X[:5]
# Out:
# array([[ 0.96985227,  0.98152247,  1.77894547,  0.95193179,  1.72531429,
#          1.74607495],
#        [-1.19737623,  1.08280781,  0.66957876, -1.29652833, -0.80173769,
#          0.72502511],
#        [-1.51615499,  1.52846331,  1.78354865, -2.31738727, -2.70413618,
#          2.72608867],
#        [ 0.05204968,  1.21785493,  1.28640506,  0.06338896,  0.06695697,
#          1.56665475],
#        [ 0.3941822 , -0.84161366,  1.28180188, -0.33174912,  0.50526348,
#         -1.07878197]])

# %%
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(X)

# %%
lin_reg.score(X,y)
# Out:
# 0.914582025610522

# %%
df = pd.read_csv('advertising.csv')
df.head()
X=df.drop(columns=['Sales']).values
y=df['Sales'].values

# %%
X.shape[0]
# Out:
# 200

# %%
train_size = int(0.7*X.shape[0])
train_size
# Out:
# 140

# %%
ix = np.random.permutation(X.shape[0])

# %%
X[ix]   #shuffled x
# Out:
# array([[219.8,  33.5,  45.1],
#        [ 89.7,   9.9,  35.7],
#        [238.2,  34.3,   5.3],
#        [227.2,  15.8,  49.9],
#        [199.8,   3.1,  34.6],
#        [ 19.6,  20.1,  17. ],
#        [ 53.5,   2. ,  21.4],
#        [ 76.4,  26.7,  22.3],
#        [137.9,  46.4,  59. ],
#        [136.2,  19.2,  16.6],
#        [ 16.9,  43.7,  89.4],
#        [ 11.7,  36.9,  45.2],
#        [240.1,  16.7,  22.9],
#        [205. ,  45.1,  19.6],
#        [123.1,  34.6,  12.4],
#        [131.1,  42.8,  28.9],
#        [163.5,  36.8,   7.4],
#        [ 13.2,  15.9,  49.6],
#        [ 23.8,  35.1,  65.9],
#        [175.1,  22.5,  31.5],
#        [214.7,  24. ,   4. ],
#        [177. ,  33.4,  38.7],
#        [139.5,   2.1,  26.6],
#        [ 43. ,  25.9,  20.5],
#        [228. ,  37.7,  32. ],
#        [261.3,  42.7,  54.7],
#        [239.9,  41.5,  18.5],
#        [ 17.2,  45.9,  69.3],
#        [129.4,   5.7,  31.3],
#        [262.9,   3.5,  19.5],
#        [ 39.5,  41.1,   5.8],
#        [ 74.7,  49.4,  45.7],
#        [ 31.5,  24.6,   2.2],
#        [120.2,  19.6,  11.6],
#        [ 50. ,  11.6,  18.4],
#        [ 38.2,   3.7,  13.8],
#        [102.7,  29.6,   8.4],
#        [  7.3,  28.1,  41.4],
#        [198.9,  49.4,  60. ],
#        [293.6,  27.7,   1.8],
#        [ 48.3,  47. ,   8.5],
#        [165.6,  10. ,  17.6],
#        [ 62.3,  12.6,  18.3],
#        [199.1,  30.6,  38.7],
#        [266.9,  43.8,   5. ],
#        [188.4,  18.1,  25.6],
#        [141.3,  26.8,  46.2],
#        [286. ,  13.9,   3.7],
#        [241.7,  38. ,  23.2],
#        [ 96.2,  14.8,  38.9],
#        [107.4,  14. ,  10.9],
#        [134.3,   4.9,   9.3],
#        [262.7,  28.8,  15.9],
#        [180.8,  10.8,  58.4],
#        [ 13.1,   0.4,  25.6],
#        [ 18.7,  12.1,  23.4],
#        [290.7,   4.1,   8.5],
#        [135.2,  41.7,  45.9],
#        [222.4,   3.4,  13.1],
#        [222.4,   4.3,  49.8],
#        [199.8,   2.6,  21.2],
#        [  8.6,   2.1,   1. ],
#        [ 97.2,   1.5,  30. ],
#        [121. ,   8.4,  48.7],
#        [109.8,  47.8,  51.4],
#        [ 68.4,  44.5,  35.6],
#        [193.7,  35.4,  75.6],
#        [ 78.2,  46.8,  34.5],
#        [ 17.9,  37.6,  21.6],
#        [ 67.8,  36.6, 114. ],
#        [239.8,   4.1,  36.9],
#        [216.8,  43.9,  27.2],
#        [289.7,  42.3,  51.2],
#        [ 18.8,  21.7,  50.4],
#        [ 57.5,  32.8,  23.5],
#        [ 73.4,  17. ,  12.9],
#        [117.2,  14.7,   5.4],
#        [ 36.9,  38.6,  65.6],
#        [225.8,   8.2,  56.5],
#        [243.2,  49. ,  44.3],
#        [149.8,   1.3,  24.3],
#        [ 66.9,  11.7,  36.8],
#        [213.5,  43. ,  33.8],
#        [191.1,  28.7,  18.2],
#        [ 75.5,  10.8,   6. ],
#        [209.6,  20.6,  10.7],
#        [265.2,   2.9,  43. ],
#        [  0.7,  39.6,   8.7],
#        [168.4,   7.1,  12.8],
#        [104.6,   5.7,  34.4],
#        [  4.1,  11.6,   5.7],
#        [ 19.4,  16. ,  22.3],
#        [151.5,  41.3,  58.5],
#        [149.7,  35.6,   6. ],
#        [284.3,  10.6,   6.4],
#        [139.3,  14.5,  10.2],
#        [172.5,  18.1,  30.7],
#        [120.5,  28.5,  14.2],
#        [171.3,  39.7,  37.7],
#        [265.6,  20. ,   0.3],
#        [177. ,   9.3,   6.4],
#        [182.6,  46.2,  58.7],
#        [197.6,   3.5,   5.9],
#        [ 94.2,   4.9,   8.1],
#        [239.3,  15.5,  27.3],
#        [156.6,   2.6,   8.3],
#        [ 28.6,   1.5,  33. ],
#        [139.2,  14.3,  25.6],
#        [230.1,  37.8,  69.2],
#        [187.8,  21.1,   9.5],
#        [202.5,  22.3,  31.6],
#        [100.4,   9.6,   3.6],
#        [ 56.2,   5.7,  29.7],
#        [ 44.7,  25.8,  20.6],
#        [ 75.1,  35. ,  52.7],
#        [237.4,   5.1,  23.5],
#        [229.5,  32.3,  74.2],
#        [ 75.3,  20.3,  32.5],
#        [  5.4,  29.9,   9.4],
#        [ 70.6,  16. ,  40.8],
#        [116. ,   7.7,  23.1],
#        [218.4,  27.7,  53.4],
#        [240.1,   7.3,   8.7],
#        [ 17.2,   4.1,  31.6],
#        [210.8,  49.6,  37.7],
#        [170.2,   7.8,  35.2],
#        [ 80.2,   0. ,   9.2],
#        [164.5,  20.9,  47.4],
#        [ 66.1,   5.8,  24.2],
#        [166.8,  42. ,   3.6],
#        [217.7,  33.5,  59. ],
#        [287.6,  43. ,  71.8],
#        [234.5,   3.4,  84.8],
#        [  8.7,  48.9,  75. ],
#        [283.6,  42. ,  66.2],
#        [220.3,  49. ,   3.2],
#        [147.3,  23.9,  19.1],
#        [215.4,  23.6,  57.6],
#        [  7.8,  38.9,  50.6],
#        [ 76.3,  27.5,  16. ],
#        [216.4,  41.7,  39.6],
#        [175.7,  15.4,   2.4],
#        [273.7,  28.9,  59.7],
#        [131.7,  18.4,  34.6],
#        [250.9,  36.5,  72.3],
#        [140.3,   1.9,   9. ],
#        [206.9,   8.4,  26.4],
#        [ 90.4,   0.3,  23.2],
#        [109.8,  14.3,  31.7],
#        [228.3,  16.9,  26.2],
#        [ 38. ,  40.3,  11.9],
#        [210.7,  29.5,   9.3],
#        [232.1,   8.6,   8.7],
#        [248.8,  27.1,  22.9],
#        [248.4,  30.2,  20.3],
#        [112.9,  17.4,  38.6],
#        [ 43.1,  26.7,  35.1],
#        [ 88.3,  25.5,  73.4],
#        [163.3,  31.6,  52.9],
#        [276.9,  48.9,  41.8],
#        [  8.4,  27.2,   2.1],
#        [281.4,  39.6,  55.8],
#        [296.4,  36.3, 100.9],
#        [ 69. ,   9.3,   0.9],
#        [184.9,  21. ,  22. ],
#        [253.8,  21.3,  30. ],
#        [ 26.8,  33. ,  19.3],
#        [ 76.4,   0.8,  14.8],
#        [224. ,   2.4,  15.6],
#        [193.2,  18.4,  65.7],
#        [ 69.2,  20.5,  18.3],
#        [206.8,   5.2,  19.4],
#        [187.9,  17.2,  17.9],
#        [ 95.7,   1.4,   7.4],
#        [110.7,  40.6,  63.2],
#        [184.9,  43.9,   1.7],
#        [125.7,  36.9,  79.2],
#        [280.7,  13.9,  37. ],
#        [213.4,  24.6,  13.1],
#        [ 44.5,  39.3,  45.1],
#        [ 27.5,   1.6,  20.7],
#        [ 59.6,  12. ,  43.1],
#        [ 97.5,   7.6,   7.2],
#        [ 87.2,  11.8,  25.9],
#        [195.4,  47.7,  52.9],
#        [ 93.9,  43.5,  50.5],
#        [292.9,  28.3,  43.2],
#        [ 25.1,  25.7,  43.3],
#        [276.7,   2.3,  23.7],
#        [255.4,  26.9,   5.5],
#        [142.9,  29.3,  12.6],
#        [218.5,   5.4,  27.4],
#        [ 85.7,  35.8,  49.3],
#        [237.4,  27.5,  11. ],
#        [ 25.6,  39. ,   9.3],
#        [204.1,  32.9,  46. ],
#        [280.2,  10.1,  21.4],
#        [ 25. ,  11. ,  29.7],
#        [220.5,  33.2,  37.9],
#        [197.6,  23.3,  14.2]])

# %%
y[ix]
# Out:
# array([19.6, 10.6, 20.7, 19.8, 16.4,  7.6,  8.1, 11.8, 15. , 13.2,  8.7,
#         7.3, 20.9, 22.6, 15.2, 16. , 18. ,  5.6,  9.2, 16.1, 17.4, 17.1,
#        10.3,  9.6, 21.5, 24.2, 23.2, 12. , 11. , 17. , 10.8, 14.7, 11. ,
#        13.2,  8.4,  7.6, 14. ,  5.5, 23.7, 20.7, 11.6, 17.6,  9.7, 18.3,
#        25.4, 19.9, 15.5, 20.9, 21.8, 12.3, 11.5, 14. , 20.2, 17.9,  5.3,
#         6.7, 17.8, 17.2, 16.5, 16.7, 15.6,  4.8, 13.2, 11.6, 16.7, 13.6,
#        19.2, 14.6,  8. , 12.5, 17.3, 22.3, 25.4,  7. , 11.8, 10.9, 11.9,
#        10.8, 18.4, 25.4, 10.1,  9.7, 21.7, 17.3, 11.9, 20.9, 17.7,  1.6,
#        16.7, 10.4,  3.2,  6.6, 16.5, 17.3, 20. , 13.4, 16.4, 14.2, 16. ,
#        17.4, 14.8, 21.2, 16.7, 14. , 20.7, 15.5,  7.3, 12.2, 22.1, 20.6,
#        16.6, 10.7,  8.7, 10.1, 12.6, 17.5, 19.7, 11.3,  5.3, 10.5, 11. ,
#        18. , 18.2,  5.9, 23.8, 16.7, 11.9, 17.5, 12.6, 19.6, 19.4, 26.2,
#        16.9,  7.2, 25.5, 24.7, 14.6, 17.1,  6.6, 12. , 22.6, 17.1, 20.8,
#        12.9, 22.2, 10.3, 17.9, 12. , 12.4, 20.5, 10.9, 18.4, 18.4, 18.9,
#        20.2, 11.9, 10.1, 12.9, 16.9, 27. ,  5.7, 24.4, 23.8, 11.3, 20.5,
#        17.6,  8.8,  9.4, 16.6, 20.2, 11.3, 17.2, 19.7, 11.9, 16. , 20.7,
#        15.9, 16.1, 17. , 10.4,  6.9,  9.7, 13.7, 10.6, 22.4, 15.3, 21.4,
#         8.5, 16.8, 19.8, 15. , 17.2, 13.3, 18.9,  9.5, 19. , 19.8,  7.2,
#        20.1, 16.6])

# %%
X_train=X[ix][:train_size]
X_test=X[ix][train_size:]
y_train, y_test=y[ix][:train_size], y[ix][train_size:]
X_train.shape, X_test.shape
# Out:
# ((140, 3), (60, 3))

# %%
y_train.shape, y_test.shape
# Out:
# ((140,), (60,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.3, random_state=42)

# %%
X_train[:5]
# Out:
# array([[156.6,   2.6,   8.3],
#        [276.7,   2.3,  23.7],
#        [205. ,  45.1,  19.6],
#        [ 66.9,  11.7,  36.8],
#        [ 76.4,  26.7,  22.3]])

# %%
stc_sc = StandardScaler()
make_poly = PolynomialFeatures(degree = 2, include_bias=False, interaction_only=True)
lin_reg = LinearRegression()

# %%
X_train = stc_sc.fit_transform(X_train)
X_train = make_poly.fit_transform(X_train)

# %%
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lin_reg.score(X_train, y_train)
# Out:
# 0.9196478612654126

# %%
from sklearn.metrics import root_mean_squared_error

# %%
y_pred = lin_reg.predict(X_train)

# %%
root_mean_squared_error(y_train, y_pred)
# Out:
# 1.4916905393172804

# %%
X_test=stc_sc.transform(X_test)
X_test = make_poly.transform(X_test)

# %%
lin_reg.score(X_test, y_test)
# Out:
# 0.8935794222827521
